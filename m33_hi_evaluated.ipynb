# %%
# %matplotlib inline
import yt
from yt.frontends.fits.misc import FITSSlicePlot, FITSProjectionPlot, FITSOffAxisSlicePlot, FITSOffAxisProjectionPlot

# %%
ds = yt.load("ALMA/m33_hi.fits", mask_nans=True)
# Out:
# yt : [WARNING  ] 2014-04-10 00:31:47,509 Cannot find time
# yt : [INFO     ] 2014-04-10 00:31:47,511 Parameters: current_time              = 0.0
# yt : [INFO     ] 2014-04-10 00:31:47,512 Parameters: domain_dimensions         = [1884 2606  200]
# yt : [INFO     ] 2014-04-10 00:31:47,512 Parameters: domain_left_edge          = [ 0.5  0.5  0.5]
# yt : [INFO     ] 2014-04-10 00:31:47,513 Parameters: domain_right_edge         = [ 1884.5  2606.5   200.5]
# yt : [INFO     ] 2014-04-10 00:31:47,514 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2014-04-10 00:31:47,514 No length conversion provided. Assuming 1 = 1 cm.

# %%
slc = FITSSlicePlot(ds, "z", ["intensity"])
slc.show()
# Out:
# yt : [INFO     ] 2014-04-10 00:31:48,459 Adding field intensity to the list of fields.
# yt : [INFO     ] 2014-04-10 00:31:48,503 Loading field plugins.
# yt : [INFO     ] 2014-04-10 00:31:48,504 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2014-04-10 00:31:48,504 Loaded astro (14 new fields)
# yt : [INFO     ] 2014-04-10 00:31:48,505 Loaded cosmology (20 new fields)
# yt : [INFO     ] 2014-04-10 00:31:48,505 Loaded fluid (55 new fields)
# yt : [INFO     ] 2014-04-10 00:31:48,506 Loaded fluid_vector (87 new fields)
# yt : [INFO     ] 2014-04-10 00:31:48,507 Loaded geometric (102 new fields)
# yt : [INFO     ] 2014-04-10 00:31:48,507 Loaded local (102 new fields)
# yt : [INFO     ] 2014-04-10 00:31:48,507 Loaded magnetic_field (108 new fields)
# yt : [INFO     ] 2014-04-10 00:31:52,906 xlim = 0.500000 1884.500000
# yt : [INFO     ] 2014-04-10 00:31:52,907 ylim = 0.500000 2606.500000
# yt : [INFO     ] 2014-04-10 00:31:52,908 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:31:54,452 xlim = 0.500000 1884.500000
# yt : [INFO     ] 2014-04-10 00:31:54,452 ylim = 0.500000 2606.500000
# yt : [INFO     ] 2014-04-10 00:31:54,454 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:31:54,605 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %%
prj = FITSProjectionPlot(ds, "z", ["intensity"])
prj.set_cmap("intensity","purple_mm")
prj.show()
# Out:
# yt : [INFO     ] 2014-04-10 00:35:34,287 Projection completed
# yt : [INFO     ] 2014-04-10 00:35:34,975 xlim = 0.500000 1884.500000
# yt : [INFO     ] 2014-04-10 00:35:34,976 ylim = 0.500000 2606.500000
# yt : [INFO     ] 2014-04-10 00:35:34,977 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:35:35,119 xlim = 0.500000 1884.500000
# yt : [INFO     ] 2014-04-10 00:35:35,120 ylim = 0.500000 2606.500000
# yt : [INFO     ] 2014-04-10 00:35:35,122 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:35:35,268 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %%
slc = FITSOffAxisSlicePlot(ds,[1.0,1.0], ["intensity"])
slc.show()
# Out:
# yt : [INFO     ] 2014-04-10 00:35:38,944 xlim = -100.000000 100.000000
# yt : [INFO     ] 2014-04-10 00:35:38,944 ylim = -100.000000 100.000000
# <img src="data:image/png;base64,..."><br>

# %%
prj = FITSOffAxisProjectionPlot(ds, [1.0,1.0], ["intensity"], depth=100.0)
# Out:
# yt : [INFO     ] 2014-04-10 00:35:41,120 xlim = -100.000000 100.000000
# yt : [INFO     ] 2014-04-10 00:35:41,120 ylim = -100.000000 100.000000
# yt : [INFO     ] 2014-04-10 00:35:41,121 zlim = -50.000000 50.000000
# yt : [INFO     ] 2014-04-10 00:35:41,121 Making a fixed resolutuion buffer of (('fits', 'intensity')) 800 by 800

# %%
prj.set_log("intensity", False)
prj.show()
# Out:
# <img src="data:image/png;base64,..."><br>
