# %%
# %matplotlib inline
import yt
from yt.frontends.fits.misc import FITSSlicePlot, FITSProjectionPlot

# %%
ds = yt.load("ALMA/ngc253_fullcube_LSB_extended_contsub_convol.fits", mask_nans=True)
# Out:
# yt : [WARNING  ] 2014-04-10 00:02:01,810 Cannot find time
# yt : [INFO     ] 2014-04-10 00:02:01,811 Parameters: current_time              = 0.0
# yt : [INFO     ] 2014-04-10 00:02:01,811 Parameters: domain_dimensions         = [640 640 634]
# yt : [INFO     ] 2014-04-10 00:02:01,812 Parameters: domain_left_edge          = [ 0.5  0.5  0.5]
# yt : [INFO     ] 2014-04-10 00:02:01,813 Parameters: domain_right_edge         = [ 640.5  640.5  634.5]
# yt : [INFO     ] 2014-04-10 00:02:01,813 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2014-04-10 00:02:01,814 No length conversion provided. Assuming 1 = 1 cm.

# %%
dd = ds.all_data()

# %%
dd.quantities.keys()
# Out:
# ['SpinParameter',
#  'MinLocation',
#  'WeightedVariance',
#  'TotalMass',
#  'AngularMomentumVector',
#  'WeightedAverageQuantity',
#  'TotalQuantity',
#  'CenterOfMass',
#  'BulkVelocity',
#  'Extrema',
#  'MaxLocation']

# %%
extrema = dd.quantities["Extrema"]("intensity")
# Out:
# yt : [INFO     ] 2014-04-09 23:56:12,257 Adding field intensity to the list of fields.
# yt : [INFO     ] 2014-04-09 23:56:12,298 Loading field plugins.
# yt : [INFO     ] 2014-04-09 23:56:12,299 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2014-04-09 23:56:12,299 Loaded astro (14 new fields)
# yt : [INFO     ] 2014-04-09 23:56:12,300 Loaded cosmology (20 new fields)
# yt : [INFO     ] 2014-04-09 23:56:12,300 Loaded fluid (55 new fields)
# yt : [INFO     ] 2014-04-09 23:56:12,301 Loaded fluid_vector (87 new fields)
# yt : [INFO     ] 2014-04-09 23:56:12,301 Loaded geometric (102 new fields)
# yt : [INFO     ] 2014-04-09 23:56:12,302 Loaded local (102 new fields)
# yt : [INFO     ] 2014-04-09 23:56:12,302 Loaded magnetic_field (108 new fields)

# %%
extrema
# Out:
# (-0.0459352768958 Jy/beam, 0.49744951725 Jy/beam)

# %%
prj1 = FITSProjectionPlot(ds, "z", ["intensity"])
prj1.show()
# Out:
# yt : [INFO     ] 2014-04-09 23:57:10,972 Projection completed
# yt : [INFO     ] 2014-04-09 23:57:11,029 xlim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:57:11,029 ylim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:57:11,030 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-09 23:57:11,053 xlim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:57:11,053 ylim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:57:11,055 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-09 23:57:11,080 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %%
pplot = yt.ProfilePlot(dd, "intensity", ["ones"], weight_field=None, n_bins=128)

# %%
pplot.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
fc = dd.cut_region("obj['intensity'] > 0.05")

# %%
prj2 = FITSProjectionPlot(ds, "z", ["intensity"], data_source=fc)
prj2.show()
# Out:
# yt : [INFO     ] 2014-04-09 23:58:04,609 Projection completed
# yt : [INFO     ] 2014-04-09 23:58:04,671 xlim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:58:04,672 ylim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:58:04,673 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-09 23:58:04,696 xlim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:58:04,697 ylim = 0.500000 640.500000
# yt : [INFO     ] 2014-04-09 23:58:04,699 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# yt : [INFO     ] 2014-04-09 23:58:04,726 Making a fixed resolution buffer of (('fits', 'intensity')) 800 by 800
# <img src="data:image/png;base64,..."><br>
