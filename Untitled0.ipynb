# %%
# %matplotlib inline
import yt
from yt.frontends.fits.api import FITSSlicePlot

# %%
ds = yt.load("/Users/jzuhone/Desktop/xray/img.fits")
# Out:
# yt : [WARNING  ] 2014-04-10 00:32:00,605 Cannot find time
# yt : [INFO     ] 2014-04-10 00:32:00,606 Parameters: current_time              = 0.0
# yt : [INFO     ] 2014-04-10 00:32:00,606 Parameters: domain_dimensions         = [256 256   1]
# yt : [INFO     ] 2014-04-10 00:32:00,607 Parameters: domain_left_edge          = [ 0.5  0.5  0.5]
# yt : [INFO     ] 2014-04-10 00:32:00,607 Parameters: domain_right_edge         = [ 256.5  256.5    1.5]
# yt : [INFO     ] 2014-04-10 00:32:00,608 Parameters: cosmological_simulation   = 0.0
# yt : [WARNING  ] 2014-04-10 00:32:00,608 No length conversion provided. Assuming 1 = 1 cm.

# %%
ds.field_list
# Out:
# yt : [INFO     ] 2014-04-10 00:32:01,376 Adding field primary to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:01,418 Loading field plugins.
# yt : [INFO     ] 2014-04-10 00:32:01,419 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2014-04-10 00:32:01,419 Loaded astro (14 new fields)
# yt : [INFO     ] 2014-04-10 00:32:01,419 Loaded cosmology (20 new fields)
# yt : [INFO     ] 2014-04-10 00:32:01,420 Loaded fluid (55 new fields)
# yt : [INFO     ] 2014-04-10 00:32:01,421 Loaded fluid_vector (87 new fields)
# yt : [INFO     ] 2014-04-10 00:32:01,422 Loaded geometric (102 new fields)
# yt : [INFO     ] 2014-04-10 00:32:01,422 Loaded local (102 new fields)
# yt : [INFO     ] 2014-04-10 00:32:01,423 Loaded magnetic_field (108 new fields)
# [('fits', 'primary')]

# %%
slc = FITSSlicePlot(ds, "z", ["primary"])
# Out:
# yt : [INFO     ] 2014-04-10 00:32:04,168 xlim = 0.500000 256.500000
# yt : [INFO     ] 2014-04-10 00:32:04,169 ylim = 0.500000 256.500000
# yt : [INFO     ] 2014-04-10 00:32:04,170 Making a fixed resolution buffer of (('fits', 'primary')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:32:04,215 xlim = 0.500000 256.500000
# yt : [INFO     ] 2014-04-10 00:32:04,215 ylim = 0.500000 256.500000
# yt : [INFO     ] 2014-04-10 00:32:04,216 Making a fixed resolution buffer of (('fits', 'primary')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:32:04,232 Making a fixed resolution buffer of (('fits', 'primary')) 800 by 800

# %%
slc.show()
# Out:
# <img src="data:image/png;base64,..."><br>

# %%
ds2 = yt.load("UnigridData/velocity_field_20.fits.gz")
# Out:
# yt : [WARNING  ] 2014-04-10 00:32:23,373 Cannot find time
# yt : [INFO     ] 2014-04-10 00:32:23,373 Parameters: current_time              = 0.0
# yt : [INFO     ] 2014-04-10 00:32:23,374 Parameters: domain_dimensions         = [200 200 200]
# yt : [INFO     ] 2014-04-10 00:32:23,375 Parameters: domain_left_edge          = [ 0.5  0.5  0.5]
# yt : [INFO     ] 2014-04-10 00:32:23,376 Parameters: domain_right_edge         = [ 200.5  200.5  200.5]
# yt : [INFO     ] 2014-04-10 00:32:23,377 Parameters: cosmological_simulation   = 0.0

# %%
ds2.index
# Out:
# yt : [INFO     ] 2014-04-10 00:32:23,493 Adding field x-velocity to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:23,493 Adding field y-velocity to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:23,494 Adding field z-velocity to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:23,537 Loading field plugins.
# yt : [INFO     ] 2014-04-10 00:32:23,537 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2014-04-10 00:32:23,538 Loaded astro (14 new fields)
# yt : [INFO     ] 2014-04-10 00:32:23,539 Loaded cosmology (20 new fields)
# yt : [INFO     ] 2014-04-10 00:32:23,539 Loaded fluid (55 new fields)
# yt : [INFO     ] 2014-04-10 00:32:23,540 Loaded fluid_vector (87 new fields)
# yt : [INFO     ] 2014-04-10 00:32:23,541 Loaded geometric (102 new fields)
# yt : [INFO     ] 2014-04-10 00:32:23,541 Loaded local (102 new fields)
# yt : [INFO     ] 2014-04-10 00:32:23,542 Loaded magnetic_field (108 new fields)

# %%
slc = yt.SlicePlot(ds2, "z", ["x-velocity"])
slc.show()
# Out:
# yt : [INFO     ] 2014-04-10 00:32:28,358 xlim = 0.500000 200.500000
# yt : [INFO     ] 2014-04-10 00:32:28,358 ylim = 0.500000 200.500000
# yt : [INFO     ] 2014-04-10 00:32:28,359 Making a fixed resolution buffer of (('fits', 'x-velocity')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:32:28,374 xlim = 0.500000 200.500000
# yt : [INFO     ] 2014-04-10 00:32:28,374 ylim = 0.500000 200.500000
# yt : [INFO     ] 2014-04-10 00:32:28,375 Making a fixed resolution buffer of (('fits', 'x-velocity')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:32:28,388 Making a fixed resolution buffer of (('fits', 'x-velocity')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %%
ds2.length_unit.in_units("pixel")
# Out:
# 1.0 pixel

# %%
ds3 = yt.load("/Users/jzuhone/Desktop/viscosity/new_fits/AM06_avisc1.0065.fits")
# Out:
# yt : [WARNING  ] 2014-04-10 00:32:28,975 Cannot find time
# yt : [INFO     ] 2014-04-10 00:32:28,976 Parameters: current_time              = 0.0
# yt : [INFO     ] 2014-04-10 00:32:28,976 Parameters: domain_dimensions         = [800 800   1]
# yt : [INFO     ] 2014-04-10 00:32:28,977 Parameters: domain_left_edge          = [ 0.5  0.5  0.5]
# yt : [INFO     ] 2014-04-10 00:32:28,978 Parameters: domain_right_edge         = [ 800.5  800.5    1.5]
# yt : [INFO     ] 2014-04-10 00:32:28,980 Parameters: cosmological_simulation   = 0.0

# %%
ds3.field_list
# Out:
# yt : [INFO     ] 2014-04-10 00:32:29,449 Adding field kt to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:29,449 Adding field magnetic_field_strength to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:29,450 Adding field magnetic_field_x to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:29,450 Adding field magnetic_field_y to the list of fields.
# yt : [INFO     ] 2014-04-10 00:32:29,505 Loading field plugins.
# yt : [INFO     ] 2014-04-10 00:32:29,506 Loaded angular_momentum (8 new fields)
# yt : [INFO     ] 2014-04-10 00:32:29,507 Loaded astro (14 new fields)
# yt : [INFO     ] 2014-04-10 00:32:29,507 Loaded cosmology (20 new fields)
# yt : [INFO     ] 2014-04-10 00:32:29,508 Loaded fluid (55 new fields)
# yt : [INFO     ] 2014-04-10 00:32:29,509 Loaded fluid_vector (87 new fields)
# yt : [INFO     ] 2014-04-10 00:32:29,511 Loaded geometric (102 new fields)
# yt : [INFO     ] 2014-04-10 00:32:29,512 Loaded local (102 new fields)
# ...

# %%
slc = yt.SlicePlot(ds3, "z", ["kt"])
slc.show()
# Out:
# yt : [INFO     ] 2014-04-10 00:32:29,984 xlim = 0.500000 800.500000
# yt : [INFO     ] 2014-04-10 00:32:29,985 ylim = 0.500000 800.500000
# yt : [INFO     ] 2014-04-10 00:32:29,986 Making a fixed resolution buffer of (('fits', 'kt')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:32:30,287 xlim = 0.500000 800.500000
# yt : [INFO     ] 2014-04-10 00:32:30,288 ylim = 0.500000 800.500000
# yt : [INFO     ] 2014-04-10 00:32:30,289 Making a fixed resolution buffer of (('fits', 'kt')) 800 by 800
# yt : [INFO     ] 2014-04-10 00:32:30,319 Making a fixed resolution buffer of (('fits', 'kt')) 800 by 800
# <img src="data:image/png;base64,..."><br>

# %%
ds3.length_unit.in_units("pixel")
# Out:
# 1.0 pixel

# %%
import warnings

# %%
warnings.filterwarnings?

# %%
ds3.length_unit.in_units("pixel")
# Out:
# 1.0 pixel
